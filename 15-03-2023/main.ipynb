# %% [markdown]
# Carga de archivo movies

# %%
import pandas as pd

df = pd.read_csv("../13-03-2023/movies.csv", sep=';')
df.plot(kind='scatter', x='user_id', y='star_wars')
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# cargar archivo customer

# %%
import pandas as pd

df2 = pd.read_csv("../13-03-2023/customer_churn_model.txt")
df2.plot()
df2.plot(kind="scatter", x="Day Mins", y="Day Charge")
# Out:
# <Axes: xlabel='Day Mins', ylabel='Day Charge'>
